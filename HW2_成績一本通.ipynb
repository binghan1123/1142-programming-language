# %% [markdown]
# <a href="https://colab.research.google.com/github/binghan1123/1142-programming-language/blob/main/HW2_%E6%88%90%E7%B8%BE%E4%B8%80%E6%9C%AC%E9%80%9A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-generativeai

# %%
import gradio as gr
import pandas as pd
from google.colab import auth
from google.auth import default

# -*- coding: utf-8 -*-
import gspread
from datetime import datetime
import google.generativeai as genai
import os
import json

# %%
from google.colab import userdata
from google import genai

# 從 Colab Secrets 中獲取 API 金鑰
api_key = userdata.get('41371209H')

# 使用獲取的金鑰配置 genai
client = genai.Client(api_key=api_key)

MODEL_ID = 'gemini-2.5-flash-lite'

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# AI works by **learning patterns from data to make predictions or decisions.**

# %%
from google.colab import userdata
from google import genai

# 從 Colab Secrets 中獲取 API 金鑰
api_key = userdata.get('41371209H')

# 使用獲取的金鑰配置 genai
client = genai.Client(api_key=api_key)

MODEL_ID = 'gemini-2.5-flash-lite'

# %%
from google.colab import userdata
from google import genai

# 從 Colab Secrets 中獲取 API 金鑰
api_key = userdata.get('41371209H')

# 使用獲取的金鑰配置 genai
client = genai.Client(api_key=api_key)

MODEL_ID = 'gemini-2.5-flash-lite'

# %%
from google.colab import userdata
from google import genai

# 從 Colab Secrets 中獲取 API 金鑰
api_key = userdata.get('41371209H')

# 使用獲取的金鑰配置 genai
client = genai.Client(api_key=api_key)

MODEL_ID = 'gemini-2.5-flash-lite'

# %%
from google.colab import userdata
from google import genai

# 從 Colab Secrets 中獲取 API 金鑰
api_key = userdata.get('41371209H')

# 使用獲取的金鑰配置 genai
client = genai.Client(api_key=api_key)

MODEL_ID = 'gemini-2.5-flash-lite'

# %%
response = client.models.generate_content(
    model = MODEL_ID, contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# AI learns from data to make predictions or decisions.

# %%
SHEET_URL = "https://docs.google.com/spreadsheets/d/1yefD7L8LSK27T-B_V4PWyk6tEUl5IGUCs9Lw8SbCGF0/edit?usp=sharing"
WORKSHEET_NAME = "工作表2"

REQUIRED_COLUMNS = ["日期", "科目", "作業成績",]

_auth_done = False
_gc = None
_ws = None

# %%
# --- 主要功能區塊 ---
def get_user_grades():
    """
    透過終端機輸入學生成績，直到使用者輸入 'q' 結束。
    """
    print("--- 準備輸入成績。輸入 'q' 來停止。---")
    grades = []
    while True:
        subject = input("請輸入科目（或輸入 'q' 停止）：")
        if subject.lower() == 'q':
            break

        grade = input(f"請輸入 {subject} 的成績：")
        try:
            grade = int(grade)
        except ValueError:
            print("成績必須是數字。請重新輸入。")
            continue

        today = datetime.now().strftime('%Y-%m-%d')
        grades.append([today, subject, grade])
        print(f"已記錄：日期: {today}, 科目: {subject}, 成績: {grade}\n")

    return grades

# %%
def get_ai_summary(grades):
    """
    呼叫 Gemini 模型來生成成績摘要與常見迷思。
    """
    # 準備給 AI 的提示
    prompt_text = "以下是學生的成績列表，請幫我根據這些成績，產出一個簡單的摘要與常見迷思整理（不評分，只做總結）。\n\n"
    for record in grades:
        date, subject, grade = record
        prompt_text += f"日期：{date}, 科目：{subject}, 成績：{grade}\n"

    print("\n--- 正在呼叫 AI 模型生成摘要... ---")
    try:
        response = client.models.generate_content(model = MODEL_ID, contents = prompt_text)
        summary = response.text
        return summary
    except Exception as e:
        print(f"呼叫 AI 時發生錯誤：{e}")
        return "AI 摘要生成失敗。"

# %%
new_grades = get_user_grades()
# Out:
# --- 準備輸入成績。輸入 'q' 來停止。---
# 請輸入科目（或輸入 'q' 停止）：國文
# 請輸入 國文 的成績：95
# 已記錄：日期: 2026-03-28, 科目: 國文, 成績: 95
#
# 請輸入科目（或輸入 'q' 停止）：英文
# 請輸入 英文 的成績：75
# 已記錄：日期: 2026-03-28, 科目: 英文, 成績: 75
#
# 請輸入科目（或輸入 'q' 停止）：數學
# 請輸入 數學 的成績：80
# 已記錄：日期: 2026-03-28, 科目: 數學, 成績: 80
#
# 請輸入科目（或輸入 'q' 停止）：q

# %%
new_grades
# Out:
# [['2026-03-28', '國文', 95], ['2026-03-28', '英文', 75], ['2026-03-28', '數學', 80]]

# %%
get_ai_summary(new_grades)
# Out:
# --- 正在呼叫 AI 模型生成摘要... ---
# '好的，這是一份根據您提供的學生成績列表所產出的簡單摘要與常見迷思整理：\n\n---\n\n### **學生成績摘要**\n\n**日期：** 2026-03-28\n\n*   **國文：** 95分\n*   **英文：** 75分\n*   **數學：** 80分\n\n**總體觀察：**\n\n*   在本次測驗中，學生在國文科目上表現最為出色，成績優異。\n*   英文成績相對國文和數學較為遜色，但仍處於及格邊緣。\n*   數學成績穩健，處於中等偏上水平。\n\n---\n\n### **常見迷思整理 (與此成績列表相關)**\n\n針對這份成績表，以下是一些與學習和成績相關的常見迷思：\n\n1.  **迷思：一次的成績決定了學生的全部能力。**\n    *   **釐清：** 這份成績僅代表了2026年3月28日的表現，可能受到當日身心狀況、考試難易度、準備程度等多種因素影響。單次的成績無法完全反映學生的長期學習能力、潛力或特定科目的總體水平。\n\n2.  **迷思：分數高的科目就一定擅長，分數低的科目就一定不擅長。**\n    *   **釐清：** 雖然分數高低有一定參考價值，但「擅長」是更深層次的理解和應用能力。例如，英文75分可能代表學生還有進步空間，但不代表他對英語完全沒有興趣或潛力。反之，95分的國文也可能是因為近期準備充分，不一定代表這是學生最突出的才能。\n\n3.  **迷思：分數之間的差距很小，所以差異不大。**\n    *   **釐清：** 在某些情況下，即使分數差距看起來不大 (例如80分和75分)，在競爭激烈的環境下，這可能代表著理解程度上的差異，或是在特定題型上的掌握程度不同。而95分和75分之間的差距，則更明顯地顯示了在該科目上的學習成效差異。\n\n4.  **迷思：只要分數達到標準，就代表學習完整了。**\n    *   **釐清：** 尤其是在像國文這樣需要深度理解和應用的科目，95分代表了優秀，但仍可能存在更進一步的精進空間。對於75分的英文，更需要思考的是達到「及格」之外，如何能夠更深入地掌握並運用。\n\n5.  **迷思：所有科目的學習方法都一樣。**\n    *   **釐清：** 國文、英文、數學等科目，往往需要不同的學習策略。例如，國文可能更側重閱讀理解、寫作和文學鑑賞；英文需要聽、說、讀、寫全方位的練習；數學則強調邏輯思考、解題技巧和公式應用。本次的成績差異，也可能與學生採用或未能採用適合該科目的學習方法有關。\n\n---\n\n希望這份摘要與迷思整理對您有幫助！'

# %%
def main():
    """
    主程式流程：輸入成績 -> 獲取 AI 摘要 -> 寫入 Google Sheet。
    """
    try:
        # 1. Google Sheet 身份驗證
        auth.authenticate_user()

        creds, _ = default()
        gc = gspread.authorize(creds)

        sh = gc.open_by_url(SHEET_URL)
        ws = sh.worksheet(WORKSHEET_NAME)





        print("--- Google Sheet 連線成功。---")

        # 檢查並確保標題列存在
        current_data = ws.get_all_values()

        # 先預設一個標籤，決定是否要新增標題
        need_header = False

        if not current_data:
            # 情況 1：表單完全是空的（連格子都沒有）
            need_header = True
        elif len(current_data[0]) == 0 or current_data[0][0] != "日期":
            # 情況 2：表單有格子但第一列是空的，或者第一格的字不是「日期」
            need_header = True

        # 根據上面的判斷結果來執行動作
        if need_header:
            ws.insert_row(REQUIRED_COLUMNS, 1)
            print(f"--- 試算表目前無標題，已自動生成標題列：{REQUIRED_COLUMNS} ---")
        else:
            print("--- 標題列已存在，不重複生成。---")


        # 2. 獲取使用者輸入的成績
        new_grades = get_user_grades()

        if not new_grades:
            print("沒有輸入任何成績，程式結束。")
            return

        # 3. 將新成績寫入 Google Sheet
        ws.append_rows(new_grades)
        print("\n--- 成績已成功寫入 Google Sheet。---")

        # 4. 獲取 AI 摘要並寫入 Google Sheet
        summary = get_ai_summary(new_grades)

        # 將 AI 摘要作為一個新的行寫入，日期在第一欄，'AI 摘要'在第二欄，完整內容在第三欄
        summary_entry = [
            datetime.now().strftime('%Y-%m-%d'),
            'AI 摘要',
            summary
        ]
        ws.append_row(summary_entry)

        print("\n--- AI 摘要已成功寫入 Google Sheet。---")
        print("以下是 AI 生成的摘要內容：")
        print("-" * 50)
        print(summary)
        print("-" * 50)

    except gspread.exceptions.APIError as e:
        print(f"Google Sheets API 錯誤：{e.response.text}")
        print("請確認：")
        print("1. 您的服務帳戶金鑰檔案正確且未過期。")
        print("2. 您已將服務帳戶的 Email 地址（在 JSON 檔案中）分享給 Google Sheet，並給予編輯權限。")
    except Exception as e:
        print(f"發生未預期的錯誤：{e}")

if __name__ == "__main__":
    main()
# Out:
# --- Google Sheet 連線成功。---
# --- 標題列已存在，不重複生成。---
# --- 準備輸入成績。輸入 'q' 來停止。---
# 請輸入科目（或輸入 'q' 停止）：國文
# 請輸入 國文 的成績：95
# 已記錄：日期: 2026-03-28, 科目: 國文, 成績: 95
#
# 請輸入科目（或輸入 'q' 停止）：英文
# 請輸入 英文 的成績：75
# 已記錄：日期: 2026-03-28, 科目: 英文, 成績: 75
#
# 請輸入科目（或輸入 'q' 停止）：q
#
# --- 成績已成功寫入 Google Sheet。---
#
# --- 正在呼叫 AI 模型生成摘要... ---
#
# --- AI 摘要已成功寫入 Google Sheet。---
# 以下是 AI 生成的摘要內容：
# --------------------------------------------------
# 好的，這是一份根據您提供的學生成績列表產生的簡單摘要與常見迷思整理：
#
# **成績摘要**
#
# *   **日期：** 2026-03-28
# *   **科目表現：**
#     *   **國文：** 95 分
#     *   **英文：** 75 分
#
# **常見迷思整理**
#
# 根據您提供的有限資訊，我們可以探討一些與學習和成績相關的常見迷思：
#
# 1.  **迷思一：分數高低直接決定學習成效。**
#     *   **說明：** 雖然分數是衡量學習成果的一個重要指標，但它並不能完全代表一個學生對知識的掌握程度、學習的過程、思考的能力或實際應用能力。例如，國文獲得高分可能代表學生對課文理解、文學賞析等方面表現出色，但這是否代表其寫作能力也同樣強勁，則需要進一步觀察。
#
# 2.  **迷思二：單一科目分數代表學生的全部能力。**
#     *   **說明：** 學生在不同科目上的表現可能會有差異，這是非常正常的。在一個科目上表現優異（如國文 95 分）不代表學生在所有科目都應該是頂尖的，反之亦然。英文成績 75 分相對較低，這可能反映了該科目學習上的挑戰，但並不代表學生在其他學術領域或非學術能力上存在問題。
#
# 3.  **迷思三：分數一旦確定，學習就結束了。**
#     *   **說明：** 考試分數是學習過程中的一個節點，而不是終點。尤其是在重視持續學習的現代教育中，分數的意義更在於反饋，幫助學生和教師了解優勢與待改進之處，進而調整學習策略，進行更深入的學習與探索。
#
# 4.  **迷思四：分數差異（如國文 95 vs 英文 75）必然意味著極大的學習差距。**
#     *   **說明：** 科目間的分數差異是常見現象，可能與個人興趣、學習方法、課程難度、老師教學風格，甚至當天的身心狀況等因素有關。這需要更全面地了解學生在不同科目上的學習投入、理解深度和過程，才能判斷是否存在真正的學習差距，以及差距的原因。
#
# **總結**
#
# 從這兩份成績來看，該學生在國文科目上表現非常出色，展現了優異的理解和掌握能力。而在英文科目上，分數則有較大的進步空間。重要的是，不應將分數視為唯一的評斷標準，而是應該結合學生的學習態度、過程、參與度以及其他多元能力的發展，給予全面性的理解和支持。
# --------------------------------------------------
